# %%
# !python img_split.py --base-json split_configs/ms_train.json
# Out:
# Loading original data!!!
# Starting loading DOTA dataset information.
# Finishing loading DOTA, get 1411 iamges, using 18.700s.
# Start splitting images!!!
# 2023-01-15 14:58:53,389 - (0.1% 1:1411) - Filename: P1895.png - width: 710   - height: 535   - Objects: 116   - Patches: 2
# 2023-01-15 14:58:55,672 - (0.1% 2:1411) - Filename: P0605.png - width: 635   - height: 1085  - Objects: 4     - Patches: 5
# 2023-01-15 14:58:57,610 - (0.2% 3:1411) - Filename: P1902.png - width: 951   - height: 811   - Objects: 27    - Patches: 5
# 2023-01-15 14:59:04,732 - (0.3% 4:1411) - Filename: P0738.png - width: 818   - height: 1826  - Objects: 66    - Patches: 13
# 2023-01-15 14:59:05,927 - (0.4% 5:1411) - Filename: P1908.png - width: 931   - height: 1077  - Objects: 146   - Patches: 8
# 2023-01-15 14:59:06,627 - (0.4% 6:1411) - Filename: P0611.png - width: 837   - height: 1613  - Objects: 8     - Patches: 11
# ...

# %%
#未完成
