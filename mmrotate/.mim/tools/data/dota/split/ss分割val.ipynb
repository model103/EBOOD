# %%
# !python img_split.py --base-json split_configs/ss_val.json
# Out:
# Loading original data!!!
# Starting loading DOTA dataset information.
# Finishing loading DOTA, get 458 iamges, using 5.606s.
# Start splitting images!!!
# 2023-01-15 16:04:45,349 - (0.2% 1:458) - Filename: P0075.png - width: 451   - height: 839   - Objects: 2     - Patches: 1
# 2023-01-15 16:04:45,459 - (0.4% 2:458) - Filename: P0150.png - width: 722   - height: 612   - Objects: 2     - Patches: 1
# 2023-01-15 16:04:45,495 - (0.7% 3:458) - Filename: P1911.png - width: 697   - height: 803   - Objects: 48    - Patches: 1
# 2023-01-15 16:04:46,561 - (0.9% 4:458) - Filename: P0189.png - width: 686   - height: 871   - Objects: 61    - Patches: 1
# 2023-01-15 16:04:47,758 - (1.1% 5:458) - Filename: P0194.png - width: 969   - height: 801   - Objects: 14    - Patches: 1
# 2023-01-15 16:04:48,382 - (1.3% 6:458) - Filename: P0589.png - width: 801   - height: 2109  - Objects: 6     - Patches: 3
# ...
